# %% [markdown]
# <a href="https://colab.research.google.com/github/sangeerthP-10/my_works/blob/main/MachineLearning/MachineLearning(day1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Linear Regression single Variable

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df=pd.DataFrame({
    'area':[2600,3000,3200,3600,4000],
    'price':[550000,565000,610000,680000,725000]
})
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
plt.scatter(df['area'],df['price'],color='g',marker='+')
plt.xlabel('Area')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['area']],df.price)
# Out:
# LinearRegression()

# %%
reg.predict([[3300]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# np.float64(180616.43835616432)

# %%
d=pd.DataFrame({
    'area' : [600, 850, 1200, 1500, 1800, 2200, 3500, 4200]
})
d
# Out:
#    area
# 0   600
# 1   850
# 2  1200
# 3  1500
# 4  1800
# 5  2200
# 6  3500
# 7  4200

# %%
price=reg.predict(d)

# %%
d['price']=price

# %%
d
# Out:
#    area          price
# 0   600  262089.041096
# 1   850  296035.958904
# 2  1200  343561.643836
# 3  1500  384297.945205
# 4  1800  425034.246575
# 5  2200  479349.315068
# 6  3500  655873.287671
# 7  4200  750924.657534

# %%
plt.scatter(df['area'],df['price'],color='g',marker='+')
plt.plot(df.area,reg.predict(df[['area']]),'b')
plt.xlabel('Area')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')
