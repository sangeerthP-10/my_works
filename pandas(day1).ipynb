# %% [markdown]
# <a href="https://colab.research.google.com/github/sangeerthP-10/my_works/blob/main/pandas(day1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('nyc_weather.csv')
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
df['Temperature'].max()
# Out:
# 50

# %%
df['EST'][df['Events']=='Rain']
# Out:
# 8      1/9/2016
# 9     1/10/2016
# 15    1/16/2016
# 26    1/27/2016
# Name: EST, dtype: object

# %%
df.fillna(0,inplace=True)
df['WindSpeedMPH'].mean()
# Out:
# np.float64(6.225806451612903)

# %%
df1=pd.read_csv('weather_data.csv')
df1
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df1.shape
# Out:
# (6, 4)

# %%
df1.head()
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain

# %%
df1.head(2)
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny

# %%
df1.tail(1)
# Out:
#         day  temperature  windspeed  event
# 5  1/6/2017           31          2  Sunny

# %%
df1[2:5]
# Out:
#         day  temperature  windspeed event
# 2  1/3/2017           28          2  Snow
# 3  1/4/2017           24          7  Snow
# 4  1/5/2017           32          4  Rain

# %%
df1[2:6:2]
# Out:
#         day  temperature  windspeed event
# 2  1/3/2017           28          2  Snow
# 4  1/5/2017           32          4  Rain

# %%
df1['temperature']
# Out:
# 0    32
# 1    35
# 2    28
# 3    24
# 4    32
# 5    31
# Name: temperature, dtype: int64

# %%
df1.temperature
# Out:
# 0    32
# 1    35
# 2    28
# 3    24
# 4    32
# 5    31
# Name: temperature, dtype: int64

# %%
df1.columns
# Out:
# Index(['day', 'temperature', 'windspeed', 'event'], dtype='object')

# %%
df1['event']='Snow'

# %%
df1
# Out:
#         day  temperature  windspeed event
# 0  1/1/2017           32          6  Snow
# 1  1/2/2017           35          7  Snow
# 2  1/3/2017           28          2  Snow
# 3  1/4/2017           24          7  Snow
# 4  1/5/2017           32          4  Snow
# 5  1/6/2017           31          2  Snow

# %%
df1.columns = df1.columns.str.strip()

# %%
type(df1['event'])
# Out:
# pandas.core.series.Series

# %%
df1
# Out:
#         day  temperature  windspeed event
# 0  1/1/2017           32          6  Snow
# 1  1/2/2017           35          7  Snow
# 2  1/3/2017           28          2  Snow
# 3  1/4/2017           24          7  Snow
# 4  1/5/2017           32          4  Snow
# 5  1/6/2017           31          2  Snow

# %%
df1[['event','day']]
# Out:
#   event       day
# 0  Snow  1/1/2017
# 1  Snow  1/2/2017
# 2  Snow  1/3/2017
# 3  Snow  1/4/2017
# 4  Snow  1/5/2017
# 5  Snow  1/6/2017

# %%
df1
# Out:
#         day  temperature  windspeed event
# 0  1/1/2017           32          6  Snow
# 1  1/2/2017           35          7  Snow
# 2  1/3/2017           28          2  Snow
# 3  1/4/2017           24          7  Snow
# 4  1/5/2017           32          4  Snow
# 5  1/6/2017           31          2  Snow

# %%
df1.loc[df1['temperature'] > 30, 'event'] = 'Sunny'

# %%
df1
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6  Sunny
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4  Sunny
# 5  1/6/2017           31          2  Sunny

# %%
df1.loc[df1['temperature']==32,'event']='Rain'

# %%
df1
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df1['temperature'].max()
# Out:
# 35

# %%
df1['temperature'].mean()
# Out:
# np.float64(30.333333333333332)

# %%
df1.describe()
# Out:
#        temperature  windspeed
# count     6.000000   6.000000
# mean     30.333333   4.666667
# std       3.829708   2.338090
# min      24.000000   2.000000
# 25%      28.750000   2.500000
# 50%      31.500000   5.000000
# 75%      32.000000   6.750000
# max      35.000000   7.000000

# %%
df1[df1.temperature>=32]
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 4  1/5/2017           32          4   Rain

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
x=df1.set_index('day')

# %%
x.loc['1/1/2017']
# Out:
# temperature      32
# windspeed         6
# event          Rain
# Name: 1/1/2017, dtype: object

# %%
x.reset_index(inplace=True)

# %%
x
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny
